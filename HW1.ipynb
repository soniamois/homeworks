# %%
ptica = int(input("Введите число от 1 до 9: "))

k= 'Вот ваши пингвинчики:'
a = '    _~_    '
b = '   (o o)   '
c = '  /  V  \  '
d = ' /(  _  )\ '
e = '   ^^ ^^   '
 
print(k)    
print(a*ptica)
print(b*ptica)
print(c*ptica)
print(d*ptica)
print(e*ptica)
# Out:
# Введите число от 1 до 9: 4
# Вот ваши пингвинчики:
#     _~_        _~_        _~_        _~_
#    (o o)      (o o)      (o o)      (o o)
#   /  V  \    /  V  \    /  V  \    /  V  \
#  /(  _  )\  /(  _  )\  /(  _  )\  /(  _  )\
#    ^^ ^^      ^^ ^^      ^^ ^^      ^^ ^^

# %%
sentence = "i am studying python"
print("Количество символов в строке: ")
print(len(sentence)) 

words = sentence.split()
print("Количество слов в строке")
print(len(words))
# Out:
# Количество символов в строке:
# 20
# Количество слов в строке
# 4

# %%
sentence = "Питон это высокоуровневый язык программирования общего назначения, ориентированный на повышение производительности разработчика и читаемости кода"
print(sentence[3])
print(sentence[-2])
print(sentence[0:5])
print(sentence[:-2])
print(sentence[1::2])
print(sentence[::2])
print(sentence[::-1])
print(sentence[::-2])
print(len(sentence))
# Out:
# о
# д
# Питон
# Питон это высокоуровневый язык программирования общего назначения, ориентированный на повышение производительности разработчика и читаемости ко
# ио т ыоорвеы зкпормиоаи беонзаеи,оиниоанйн оыеи ривдтлнсирзаочк  иамсикд
# Птнэовскуонвйяы ргамрвняощг анчня ретрвны апвшнепозоиеьот арбтиаичтеот оа
# адок итсомеатич и акичтобарзар итсоньлетидовзиорп еинешывоп ан йыннаворитнеиро ,яинечанзан огещбо яинавориммаргорп кызя йывенворуокосыв отэ нотиП
# ао тоетчиаитбра тоьеиозопеншвпа ынвртер янчна гщоянврмагр ыяйвноуксвоэнтП
# 145

# %%
s = input("Введите слово: ") 

if s.lower() == s[::-1].lower():
    print ("Yes")
else: 
    print ("No")
# Out:
# Введите слово: lkdlskak
# No

# %%
s = input("Введите какое-нибудь слово: ") 

text = ['законы', 'физики', 'рядом', 'с', 'черной', 'дырой', 'уже', 'не', 'работают', 'в', 'том', 'представлении', 'в', 'котором', 'мы', 'привыкли', 'пространство', 'время', 'искривляется', 'и', 'все', 'события', 'протекают', 'уже', 'совсем', 'по', 'другому', 'словно', 'пылесос', 'черная', 'дыра', 'поглощает', 'все', 'что', 'находится', 'около', 'нее', 'планеты', 'астероиды', 'свет', 'и', 'прочее', 'ранее', 'считалось', 'что', 'черная', 'дыра', 'ничего', 'не', 'излучает', 'но', 'как', 'доказал', 'стивен', 'хокинг', 'черная', 'дыра', 'излучает', 'антивещество', 'то', 'есть', 'поедает', 'вещество', 'и', 'выделяет', 'антивещество', 'ранее', 'думали', 'что', 'если', 'кинуть', 'в', 'черную', 'дыру', 'человека', 'то', 'ему', 'труба', 'порвет', 'на', 'субатомы', 'но', 'как', 'оказалось', 'по', 'некоторым', 'уравнениям', 'есть', 'определенные', 'траектории', 'путешествия', 'сквозь', 'черную', 'дыру', 'чтоб', 'чувствовать', 'себя', 'нормально', 'правда', 'не', 'ясно', 'что', 'будет', 'за', 'ней', 'другой', 'мир', 'или', 'ничего', 'область', 'вокруг', 'черной', 'дыры', 'которая', 'интересна', 'называется', 'горизонтом', 'событий', 'если', 'туда', 'полететь', 'не', 'зная', 'волшебное', 'уравнение', 'то', 'будет', 'конечно', 'не', 'очень', 'наблюдатель', 'будет', 'видеть', 'как', 'космический', 'корабль', 'влетает', 'в', 'горизонт', 'событий', 'и', 'крайне', 'медленно', 'потом', 'отдаляется', 'пока', 'не', 'застынет', 'в', 'центре', 'у', 'самого', 'же', 'космонавта', 'дела', 'будут', 'идти', 'совсем', 'по', 'другому', 'искривленное', 'пространство', 'будет', 'лепить', 'из', 'него', 'как', 'из', 'пластилина', 'различные', 'формы', 'пока', 'наконец', 'не', 'разорвет', 'все', 'на', 'субатомы', 'но', 'для', 'внешнего', 'наблюдателя', 'космонавт', 'навсегда', 'останется', 'улыбающимся', 'и', 'махающим', 'в', 'иллюминатор', 'застывшим', 'изображением']


if s not in words:
    print("Грустно, но такого слова нет, но мы его добавим!")
    text.append(s)
    print(text)
else:
    print("Это слово есть! Оно встречается в тексте раз: ")
    print(text.count(s))
# Out:
# Введите какое-нибудь слово: dlskldks
# Грустно, но такого слова нет, но мы его добавим!
# ['законы', 'физики', 'рядом', 'с', 'черной', 'дырой', 'уже', 'не', 'работают', 'в', 'том', 'представлении', 'в', 'котором', 'мы', 'привыкли', 'пространство', 'время', 'искривляется', 'и', 'все', 'события', 'протекают', 'уже', 'совсем', 'по', 'другому', 'словно', 'пылесос', 'черная', 'дыра', 'поглощает', 'все', 'что', 'находится', 'около', 'нее', 'планеты', 'астероиды', 'свет', 'и', 'прочее', 'ранее', 'считалось', 'что', 'черная', 'дыра', 'ничего', 'не', 'излучает', 'но', 'как', 'доказал', 'стивен', 'хокинг', 'черная', 'дыра', 'излучает', 'антивещество', 'то', 'есть', 'поедает', 'вещество', 'и', 'выделяет', 'антивещество', 'ранее', 'думали', 'что', 'если', 'кинуть', 'в', 'черную', 'дыру', 'человека', 'то', 'ему', 'труба', 'порвет', 'на', 'субатомы', 'но', 'как', 'оказалось', 'по', 'некоторым', 'уравнениям', 'есть', 'определенные', 'траектории', 'путешествия', 'сквозь', 'черную', 'дыру', 'чтоб', 'чувствовать', 'себя', 'нормально', 'правда', 'не', 'ясно', 'что', 'будет', 'за', 'ней', 'другой', 'мир', 'или', 'ничего', 'область', 'вокруг', 'черной', 'дыры', 'которая', 'интересна', 'называется', 'горизонтом', 'событий', 'если', 'туда', 'полететь', 'не', 'зная', 'волшебное', 'уравнение', 'то', 'будет', 'конечно', 'не', 'очень', 'наблюдатель', 'будет', 'видеть', 'как', 'космический', 'корабль', 'влетает', 'в', 'горизонт', 'событий', 'и', 'крайне', 'медленно', 'потом', 'отдаляется', 'пока', 'не', 'застынет', 'в', 'центре', 'у', 'самого', 'же', 'космонавта', 'дела', 'будут', 'идти', 'совсем', 'по', 'другому', 'искривленное', 'пространство', 'будет', 'лепить', 'из', 'него', 'как', 'из', 'пластилина', 'различные', 'формы', 'пока', 'наконец', 'не', 'разорвет', 'все', 'на', 'субатомы', 'но', 'для', 'внешнего', 'наблюдателя', 'космонавт', 'навсегда', 'останется', 'улыбающимся', 'и', 'махающим', 'в', 'иллюминатор', 'застывшим', 'изображением', 'dlskldks']
